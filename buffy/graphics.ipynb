# %%
import importlib
from robot import Robot
from buffer import Buffer
from simulation import Simulation
from sys import argv
import matplotlib.pyplot as plt

# %%
def debug(*argv):
    goal = float(argv[0])

    # Initialize the simulation
    s = Simulation(pka = 7, c = 0.5, v = 1)
    # Initialize the buffer, using the simulation
    b = Buffer(s, 4)

    # Create buffy
    buffy = Robot(goal, b)
    # Let buffy do its thing
    buffy.run()

    return buffy.read_mind()

# %%
# %matplotlib inline

# %%
data = debug(9)

# %%
fig, ax = plt.subplots()
ax.scatter(data[:,0], data[:,1])
lim = ax.get_xlim()
ax.set_xlim(lim[1], lim[0])
print(len(data))
plt.show()
# Out:
# 31

# %%
import numpy as np

# %%
high = abs(np.gradient([data[-5], data[-1]])[1][-1][0])

# %%
low = np.gradient(data[:2])[1][-1][0]

# %%
import math

# %%
5-math.log(low)
# Out:
# 2.899853779344561

# %%
c = 7
g = 9
slope = 4

# %%
factor = 5 - slope
diff = abs(c-g)
print(factor, diff)
# Out:
# 1 2

# %%
data[:,1]
# Out:
# array([7.17121003, 7.15534207, 7.13857468, 7.12157894, 7.10502594,
#        7.08958675, 7.07593247, 7.06473418, 7.05666296, 7.0523899 ,
#        7.05258607, 7.05792258, 7.06907049, 7.0867009 , 7.11148488,
#        7.14409353, 7.18519793, 7.23546916, 7.29557831, 7.36619645,
#        7.44799468, 7.54164409, 7.64781574, 7.76718073, 7.90041015,
#        8.04817507, 8.21114659, 8.38999578, 8.58539373, 8.79801153,
#        9.02852025])

# %%
import time

# %%
from matplotlib import animation

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

fig, ax = plt.subplots()
xdata, ydata = [], []
ln, = plt.plot([], [], 'ro', animated=True)

def init():
    ax.set_xlim(0, 2*np.pi)
    ax.set_ylim(-1, 1)
    return ln,

def update(frame):
    xdata.append(frame)
    ydata.append(np.sin(frame))
    ln.set_data(xdata, ydata)
    return ln,

ani = FuncAnimation(fig, update, frames=np.linspace(0, 2*np.pi, 128),
                    init_func=init, blit=True)
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-f1eb0849f1c8> in <module>()
#       5 ax.set_xlim(lim[1], lim[0])
#       6 ln = ax.scatter([],[], c="C0", zorder=1)
# ----> 7 ln.set(data=[[-20],[7.5]])
#
# /usr/lib/python3.6/site-packages/matplotlib/artist.py in set(self, **kwargs)
#     991                    key=lambda x: (self._prop_order.get(x[0], 0), x[0])))
#     992
# --> 993         return self.update(props)
#     994
#     995     def findobj(self, match=None, include_self=True):
#
# /usr/lib/python3.6/site-packages/matplotlib/artist.py in update(self, props)
#     886         try:
#     887             ret = [_update_property(self, k, v)
# --> 888                    for k, v in props.items()]
#     889         finally:
#     890             self.eventson = store
#
# /usr/lib/python3.6/site-packages/matplotlib/artist.py in <listcomp>(.0)
#     886         try:
#     887             ret = [_update_property(self, k, v)
# --> 888                    for k, v in props.items()]
#     889         finally:
#     890             self.eventson = store
#
# /usr/lib/python3.6/site-packages/matplotlib/artist.py in _update_property(self, k, v)
#     879                 func = getattr(self, 'set_' + k, None)
#     880                 if not callable(func):
# --> 881                     raise AttributeError('Unknown property %s' % k)
#     882                 return func(v)
#     883
#
# AttributeError: Unknown property data

# %%
fig = plt.gcf()

# %%
plt.show()

# %%
scat = plt.scatter([],[])

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-6f31eaab1ad5> in <module>()
# ----> 1 scat[0]
#
# TypeError: 'PathCollection' object does not support indexing

# %%
import importlib
from robot import Robot
from buffer import Buffer
from simulation import Simulation
from sys import argv
import matplotlib.pyplot as plt
import time
from IPython import display
import numpy as np

# %%
def debug(*argv):
    goal = float(argv[0])

    # Initialize the simulation
    s = Simulation(pka = 7, c = 0.5, v = 1, start = 4)
    # Initialize the buffer, using the simulation
    b = Buffer(s, 4)

    # Create buffy
    buffy = Robot(goal, b)
    # Let buffy do its thing
    buffy.run()

    return buffy

# %%
buffy = debug(9)

# %%
data = buffy.read_mind()

# %%
poly = buffy.b.s.poly

# %%
real_data = np.array([[x,np.polyval(poly, x)] for x in np.arange(0.2, -1.2, -0.02)])

# %%
# %matplotlib inline

# %%
data
# Out:
# array([[ 0.00000000e+00,  3.48842691e+00],
#        [-1.60000000e-05,  3.60583788e+00],
#        [-3.20000000e-05,  3.54356583e+00],
#        ...,
#        [-9.57600000e-01,  8.70131181e+00],
#        [-9.57616000e-01,  8.89649417e+00],
#        [-9.57632000e-01,  8.60220974e+00]])

# %%
fig, ax = plt.subplots()
ax.plot(real_data[:,0],real_data[:,1], c='C1')
lim = ax.get_xlim()
ax.set_xlim(lim[1], lim[0])
x = []
y = []
ax.set_title = "pH over time"
ax.set_xlabel = "H+ added"
ax.set_ylabel = "pH"
for t, p in data[::3000]:
    x.append(t)
    y.append(p)
    display.clear_output(wait=True)
    display.display(plt.gcf())
    ax.plot(x, y, marker='o', c='C0')
    time.sleep(0.5)
plt.close()
plt.show()

# %%
fig, ax = plt.subplots()
# Out:
# <div id='0dce4bff-f4f8-4232-94dd-a278fb577155'></div>
# <div id='f02bbb5f-9898-4ec9-8246-38830e9b59ad'></div>
